# %%
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
import scipy
import seaborn as sns

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
import sys
sys.path.append("/Users/nspies/code/spiesbio/")

# %%
import spiesbio as sb

# %%
g = sb.plot.Grid(5, ncols=3)
for i, ax in enumerate(g):
    x = pd.Series(np.random.randint(0, 100_000, size=200), name="Independent Variable")
    y = pd.Series(x + np.random.randint(-5, 50, size=200), name="Dependent Variable")
    sb.plot.scatter(x, y, ax=ax, log="y")
    sb.plot.format_ticklabels(ax=ax)
    ax.text(0.5, 0.5, i, fontsize=50, horizontalalignment='center', transform=ax.transAxes)
    if i >=4: break
